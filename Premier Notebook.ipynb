# %% [markdown]
# <a href="https://colab.research.google.com/github/ImaneS-COde/ECM_DDEFI_2526_Cours1/blob/main/Premier%20Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Première fonction de Python
print("Hello Centrale Marseille")
# Out:
# Hello Centrale Marseille

# %%
# Variable
a="Alice"
height=1.85
is_student=True

# %%
height
# Out:
# 1.85

# %%
# Il existe la maj
print(f"{a} fait {height} en m, et est une étudiante {is_student}")
# Out:
# Alice fait 1.85 en m, et est une étudiante True

# %%
print("mnt on MERGE")
# Out:
# mnt on MERGE

# %%
import numpy as np
import pandas as pd
